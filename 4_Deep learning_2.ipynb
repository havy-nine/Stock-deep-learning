# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split #데이터셋을 분리하기 위해 import
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager   
import numpy as np
import tensorflow as tf

# %%
df = pd.read_csv('D:\\ai\\final_term\\Google_stock.csv')
df1 = df.drop(df.columns[0:2], axis = 'columns')
df2 = df1.astype(int)

# %%
#상위 10개의 set을 뽑아 확인하기
df2.head(10)
# Out:
#      시가    고점    저점    종가      거래량  증감  종가-시가  최대-최소
# 0  1351  1358  1348  1356  1469900   1      4      9
# 1  1363  1363  1349  1349  3315000   1     13     14
# 2  1355  1359  1346  1348   883100   1      7     13
# 3  1348  1350  1342  1343   347500   0      4      7
# 4  1346  1361  1344  1360   667500   1     14     16
# 5  1362  1364  1349  1351  1038400   0     11     15
# 6  1350  1353  1334  1336  1050900   0     13     18
# 7  1330  1338  1329  1337   961800   1      6      8
# 8  1341  1368  1341  1367  1406600   0     25     26
# 9  1347  1372  1345  1360  1186400   0     12     26

# %%
#속성과 클래스로 데이터 분리: 클래스는 증감으로 할거임. 
dataset = df2.values
X= dataset[:,4:8]
Y= dataset[:,5]

# %%
type(X)
# Out:
# numpy.ndarray

# %%
#데이터셋을 traing dataset과 test dataset으로 분리
seed = 0
np.random.seed(3)
tf.random.set_seed(3)

#학습 데이터셋은 80%로 테스트 데이터셋은 20%.

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=seed)

# %%
X_train
# Out:
# array([[1437700,       0,      21,      27],
#        [1576600,       0,       5,      35],
#        [2175400,       0,      12,      28],
#        [3861500,       0,      26,      74],
#        [1826700,       1,      24,      33],
#        [1246800,       1,       9,      31],
#        [1173700,       1,       4,      11],
#        [3570900,       1,      38,      65],
#        [1652300,       0,       3,      14],
#        [1106500,       0,      15,      29],
#        [2387300,       1,      34,      42],
#        [ 961800,       1,       6,       8],
#        [3793600,       0,       0,      34],
#        [2535400,       0,       2,      44],
#        [1362800,       1,       5,      40],
#        [1172300,       1,      11,      19],
#        [1685800,       1,       0,      30],
#        [1903500,       0,      11,      26],
#        [1264000,       1,       2,      16],
#        [1320900,       0,       0,      26],
#        [1433600,       0,      22,      36],
# ...

# %%
model = Sequential()
model.add(Dense(30, input_dim=4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#loss를 binary로 하고 모델 실행 
hist = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, verbose=2)
# Out:
# Train on 202 samples, validate on 51 samples
# Epoch 1/100
# 202/202 - 1s - loss: 55864.8965 - accuracy: 0.5594 - val_loss: 36079.9827 - val_accuracy: 0.5686
# Epoch 2/100
# 202/202 - 0s - loss: 27316.9556 - accuracy: 0.5594 - val_loss: 10349.3086 - val_accuracy: 0.5686
# Epoch 3/100
# 202/202 - 0s - loss: 6190.0786 - accuracy: 0.4901 - val_loss: 9881.5579 - val_accuracy: 0.4314
# Epoch 4/100
# 202/202 - 0s - loss: 8160.2769 - accuracy: 0.4406 - val_loss: 1663.7231 - val_accuracy: 0.4314
# Epoch 5/100
# 202/202 - 0s - loss: 3235.7904 - accuracy: 0.5099 - val_loss: 3190.3836 - val_accuracy: 0.5686
# Epoch 6/100
# 202/202 - 0s - loss: 2469.0971 - accuracy: 0.4505 - val_loss: 3007.3574 - val_accuracy: 0.4314
# Epoch 7/100
# 202/202 - 0s - loss: 2029.0266 - accuracy: 0.4406 - val_loss: 1396.6801 - val_accuracy: 0.5686
# Epoch 8/100
# 202/202 - 0s - loss: 625.0656 - accuracy: 0.5099 - val_loss: 653.1118 - val_accuracy: 0.5686
# Epoch 9/100
# ...

# %%
#모델 평가하기.

# %%
a,b = model.evaluate(x=X_test, y=Y_test, verbose=0) 
print("Evaluate with test dataset : Loss = {:.4f}".format(a))      
print("Evaluate with test dataset : Accuracy = {:.4f}".format(b))
# Out:
# Evaluate with test dataset : Loss = 105.1826
# Evaluate with test dataset : Accuracy = 0.4314

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 30)                150
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 31
# ...
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
#한글폰트를 쓰기위해 입력
font_path = "C:\\Windows\\Fonts\\HMKMMAG.TTF"
font_name = matplotlib.font_manager.FontProperties(fname=font_path).get_name()

plt.rc('font', family=font_name, size=14) 
plt.figure(figsize=(6,4))
plt.title('training data와 test data의 정확도 비교 ', fontsize=16)

plt.plot(hist.history['loss'])      
plt.plot(hist.history['val_loss'])  

plt.plot(hist.history['accuracy'])       
plt.plot(hist.history['val_accuracy']) 

plt.legend(['loss','val_loss','accuracy', 'val_accuracy' ])   #4가지 범례
plt.grid()
plt.show()

# %%
#전혀 관련이 없는것을 알 수 있다..
from keras.models import load_model
model.save('4_Deep learning_2_saved.h5')
# Out:
# Using TensorFlow backend.
